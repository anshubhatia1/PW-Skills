# %% [markdown]
# Sure, let's address each question one by one:
#
# ### Q1. Pearson Correlation Coefficient:
#
# Pearson correlation coefficient measures the linear relationship between two continuous variables. Here, you have data on the amount of time students spend studying and their final exam scores.
#
# Let's denote:
# - \( X \): Amount of time spent studying.
# - \( Y \): Final exam scores.
#
# Assuming you have collected paired data for 50 students, you can calculate Pearson correlation coefficient \( r \) using the formula:
#
# \[ r = \frac{\sum (X_i - \bar{X})(Y_i - \bar{Y})}{\sqrt{\sum (X_i - \bar{X})^2 \sum (Y_i - \bar{Y})^2}} \]
#
# Where:
# - \( \bar{X} \) and \( \bar{Y} \) are the means of \( X \) and \( Y \) respectively.
#
# Interpretation:
# - \( r = 1 \): Perfect positive linear correlation (as time spent studying increases, exam scores increase).
# - \( r = -1 \): Perfect negative linear correlation (as time spent studying increases, exam scores decrease).
# - \( r = 0 \): No linear correlation.
#
# ### Q2. Spearman's Rank Correlation:
#
# Spearman's rank correlation measures the monotonic relationship between two variables. Monotonic means that as one variable increases, the other either consistently increases or decreases (but not necessarily at a constant rate).
#
# Here, you have data on the amount of sleep individuals get and their overall job satisfaction level.
#
# Let's denote:
# - \( X \): Amount of sleep individuals get.
# - \( Y \): Job satisfaction level (ranked on a scale of 1 to 10).
#
# Calculate Spearman's rank correlation \( \rho \):
# - Convert both variables \( X \) and \( Y \) into ranks.
# - Use the formula for Spearman's rank correlation coefficient.
#
# Interpretation:
# - \( \rho = +1 \): Perfect monotonic positive correlation.
# - \( \rho = -1 \): Perfect monotonic negative correlation.
# - \( \rho = 0 \): No monotonic correlation.
#
# ### Q3. Comparing Pearson and Spearman Correlation:
#
# For the relationship between hours of exercise per week and BMI:
#
# - **Pearson correlation coefficient (r):** Measures the linear relationship between exercise hours and BMI.
# - **Spearman's rank correlation (\( \rho \)):** Measures the monotonic relationship between exercise hours and BMI ranks.
#
# Calculate both coefficients and compare:
# - If the relationship is linear, Pearson correlation will be more appropriate.
# - If the relationship is monotonic (but not necessarily linear), Spearman's correlation might be more appropriate.
#
# ### Q4. Pearson Correlation Coefficient:
#
# For the relationship between hours spent watching television per day and level of physical activity:
#
# Let's denote:
# - \( X \): Hours spent watching TV per day.
# - \( Y \): Level of physical activity.
#
# Calculate Pearson correlation coefficient \( r \):
# - Use the formula for Pearson correlation coefficient as mentioned earlier.
#
# Interpretation:
# - \( r \) close to -1 or +1 indicates a strong negative or positive linear relationship respectively.
# - \( r \) close to 0 indicates no linear relationship.
#
# ---
#
# If you need specific calculations or further details on any of these questions, feel free to ask!
